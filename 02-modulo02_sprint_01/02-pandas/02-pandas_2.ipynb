# %% [markdown]
# ### Pair Programming Pandas II

# %%
# Lo primero, importamos las librerías:

import pandas as pd
import pickle
import numpy as np

# %% [markdown]
# 1. Id cargando todos los ficheros en vuestro jupyter.
#
# Para poner el práctica el read_clipboard elegir alguna tabla que os podaís encontrar en google y usad dicho método para traer los datos al jupyter notebook.

# %%
#pickle
archivo_pickle=  pd.read_pickle('datos/02-algas.pickle')
archivo_pickle
# Out:
#       Unnamed: 0       lon      lat    locality  year  month    kingdom  \
# 0             22  -70.7167  43.0750  New Castle  1900    5.0  Chromista
# 1             23  -70.7167  43.0750  New Castle  1900    5.0  Chromista
# 2             24  -70.7167  43.0750  New Castle  1900    5.0    Plantae
# 3             33 -158.1170  21.5833     Haleiwa  1900    6.0    Plantae
# 4             35   -7.0000  62.1800     Hvalvík  1900    6.0  Chromista
# ...          ...       ...      ...         ...   ...    ...        ...
# 6691       27748 -125.1548  48.8266    Bamfield  2020    2.0  Chromista
# 6692       27752 -125.1549  48.8264    Bamfield  2020    2.0  Chromista
# 6693       27759 -125.1550  48.8264    Bamfield  2020    2.0    Plantae
# 6694       27776 -125.1549  48.8264    Bamfield  2020    2.0  Chromista
# 6695       27781 -125.1542  48.8269    Bamfield  2020    2.0    Plantae
#
#                 class        family      genus            species  \
# ...

# %% [markdown]
# - .csv

# %%
df_csv = pd.read_csv("datos/quejas.csv", encoding="latin", sep = ";" )
df_csv.head()
# Out:
#     tipo                   estado canal_entrada        fecha_entrada  \
# 0  Queja  Recepcionada por Unidad      INTERNET  2022-01-28 00:00:00
# 1  Queja  Recepcionada por Unidad      INTERNET  2022-03-28 00:00:00
# 2  Queja  Recepcionada por Unidad      INTERNET  2022-03-23 00:00:00
# 3  Queja  Recepcionada por Unidad      INTERNET  2022-01-24 00:00:00
# 4  Queja  Recepcionada por Unidad      INTERNET  2022-03-29 00:00:00
#
#   fecha_contestacion                                         consejeria  \
# 0                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# 1                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# 2                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# 3                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# 4                NaN  Consejería de Medio Ambiente, Vivienda y Agric...
#
#                                  unidad_descripcion     tema subtema
# ...

# %% [markdown]
# - .json

# %%
df_json = pd.read_json("datos/quejas.json")
df_json.head()
# Out:
#                                                 data
# 0  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 1  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 2  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 3  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 4  {'unidad_descripcion': 'D.G. de Descarbonizaci...

# %% [markdown]
# - .xlsx (Excel)

# %%
df_xlsx = pd.read_excel("datos/quejas2.xlsx")
df_xlsx.head()
# Out:
#         DESCRIPCION_TEMA                                DESCRIPCION_SUBTEMA
# 0  ATENCIÓN AL CIUDADANO                         ADMINISTRACIÓN ELECTRÓNICA
# 1  ATENCIÓN AL CIUDADANO                                    FUNCIÓN PÚBLICA
# 2  ATENCIÓN AL CIUDADANO  OFICINAS DE ATENCIÓN AL CIUDADANO DE LA COMUNI...
# 3  ATENCIÓN AL CIUDADANO     OFICINAS DE REGISTRO DE LA COMUNIDAD DE MADRID
# 4  ATENCIÓN AL CIUDADANO                                              OTROS

# %% [markdown]
# Para poner el práctica el read_clipboard elegid alguna tabla que os podaís encontrar en google y usad dicho método  para traer los datos al jupyter notebook.

# %%
archivo_clipboard = pd.read_clipboard()
archivo_clipboard
# Out:
#    NAME  ID  MATH  ENGLISH
# 0  Ravi   1    30       20
# 1  Raju   2    40       30
# 2  Alex   3    50       40

# %% [markdown]
# Una vez que los hayáis cargado, guardad esos datos en los siguientes formatos:
#
# - csv
# - excel
# - json
# - picke

# %%
df_csv.to_csv("datos/tabla.csv")

# %%
df_xlsx.to_excel("datos/tabla.xlsx")

# %%
df_json.to_json("datos/tabla.json")

# %%
archivo_pickle.to_pickle("datos/tabla.pickle")
