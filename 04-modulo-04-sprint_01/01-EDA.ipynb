# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sidetable

# %%
df1 = pd.read_csv('data/music_health_survey_results.csv',index_col=0)
df1.head()
# Out:
#                      Age Primary streaming service  Hours per day  \
# Timestamp
# 8/27/2022 19:29:02  18.0                   Spotify            3.0
# 8/27/2022 19:57:31  63.0                   Pandora            1.5
# 8/27/2022 21:28:18  18.0                   Spotify            4.0
# 8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#                    While working Instrumentalist Composer         Fav genre  \
# Timestamp
# 8/27/2022 19:29:02           Yes             Yes      Yes             Latin
# 8/27/2022 19:57:31           Yes              No       No              Rock
# 8/27/2022 21:28:18            No              No       No  Video game music
# 8/27/2022 21:40:40           Yes              No      Yes              Jazz
# 8/27/2022 21:54:47           Yes              No       No               R&B
#
#                    Exploratory Foreign languages    BPM  ...  Frequency [R&B]  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 736 entries, 8/27/2022 19:29:02 to 11/9/2022 1:55:20
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           735 non-null    float64
#  1   Primary streaming service     735 non-null    object
#  2   Hours per day                 736 non-null    float64
#  3   While working                 733 non-null    object
#  4   Instrumentalist               732 non-null    object
#  5   Composer                      735 non-null    object
#  6   Fav genre                     736 non-null    object
#  7   Exploratory                   736 non-null    object
#  8   Foreign languages             732 non-null    object
#  9   BPM                           629 non-null    float64
#  10  Frequency [Classical]         736 non-null    object
#  11  Frequency [Country]           736 non-null    object
# ...

# %%
print(f'Los duplicados de este df son:{df1.duplicated().sum()}')
# Out:
# Los duplicados de este df son:0

# %%
print(f'Los nulos de este df son:')
df1.stb.missing()
# Out:
# Los nulos de este df son:
#                               missing  total    percent
# BPM                               107    736  14.538043
# Music effects                       8    736   1.086957
# Foreign languages                   4    736   0.543478
# Instrumentalist                     4    736   0.543478
# While working                       3    736   0.407609
# Primary streaming service           1    736   0.135870
# Age                                 1    736   0.135870
# Composer                            1    736   0.135870
# Insomnia                            0    736   0.000000
# OCD                                 0    736   0.000000
# Frequency [Lofi]                    0    736   0.000000
# Depression                          0    736   0.000000
# Anxiety                             0    736   0.000000
# Frequency [Video game music]        0    736   0.000000
# Frequency [Rock]                    0    736   0.000000
# ...

# %%
df1
# Out:
#                       Age Primary streaming service  Hours per day  \
# Timestamp
# 8/27/2022 19:29:02   18.0                   Spotify            3.0
# 8/27/2022 19:57:31   63.0                   Pandora            1.5
# 8/27/2022 21:28:18   18.0                   Spotify            4.0
# 8/27/2022 21:40:40   61.0             YouTube Music            2.5
# 8/27/2022 21:54:47   18.0                   Spotify            4.0
# ...                   ...                       ...            ...
# 10/30/2022 14:37:28  17.0                   Spotify            2.0
# 11/1/2022 22:26:42   18.0                   Spotify            1.0
# 11/3/2022 23:24:38   19.0   Other streaming service            6.0
# 11/4/2022 17:31:47   19.0                   Spotify            5.0
# 11/9/2022 1:55:20    29.0             YouTube Music            2.0
#
#                     While working Instrumentalist Composer         Fav genre  \
# Timestamp
# ...

# %%
nulos = df1.get(df1['BPM'].isnull())
nulos.head()
# Out:
#                      Age Primary streaming service  Hours per day  \
# Timestamp
# 8/27/2022 22:51:15  18.0                   Spotify            3.0
# 8/27/2022 23:04:00   NaN                   Spotify            3.0
# 8/27/2022 23:19:52  17.0                   Spotify            2.0
# 8/28/2022 10:30:22  20.0               Apple Music            5.0
# 8/28/2022 10:54:30  19.0                   Spotify            6.0
#
#                    While working Instrumentalist Composer Fav genre  \
# Timestamp
# 8/27/2022 22:51:15           Yes             Yes       No   Country
# 8/27/2022 23:04:00           Yes              No       No   Hip hop
# 8/27/2022 23:19:52            No              No       No       Pop
# 8/28/2022 10:30:22           Yes             Yes       No      Rock
# 8/28/2022 10:54:30           Yes             Yes       No     Metal
#
#                    Exploratory Foreign languages  BPM  ... Frequency [R&B]  \
# ...

# %%
df1.Anxiety.unique()
# Out:
# array([ 3. ,  7. ,  9. ,  8. ,  4. ,  5. ,  2. ,  1. ,  6. , 10. ,  0. ,
#         7.5])

# %%
mapa = { 0:'Baja' ,  1:'Baja', 2:'Baja', 3:'Media',4:'Media',5:'Media',6:'Media', 7:'Alta', 7.5:'Alta', 8.:'Alta',9:'Alta',10:'Alta'}

# %%
df1['anxiety_map']= df1['Anxiety'].map(mapa)

# %%
df1.head()
# Out:
#                      Age Primary streaming service  Hours per day  \
# Timestamp
# 8/27/2022 19:29:02  18.0                   Spotify            3.0
# 8/27/2022 19:57:31  63.0                   Pandora            1.5
# 8/27/2022 21:28:18  18.0                   Spotify            4.0
# 8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#                    While working Instrumentalist Composer         Fav genre  \
# Timestamp
# 8/27/2022 19:29:02           Yes             Yes      Yes             Latin
# 8/27/2022 19:57:31           Yes              No       No              Rock
# 8/27/2022 21:28:18            No              No       No  Video game music
# 8/27/2022 21:40:40           Yes              No      Yes              Jazz
# 8/27/2022 21:54:47           Yes              No       No               R&B
#
#                    Exploratory Foreign languages    BPM  ...  Frequency [Rap]  \
# ...

# %%
df1.anxiety_map.isnull().sum()
# Out:
# 0

# %%
df1.Depression.unique()
# Out:
# array([ 0. ,  2. ,  7. ,  8. ,  3. ,  1. ,  4. ,  5. ,  9. , 10. ,  6. ,
#         3.5])

# %%
mapa1 = { 0:'Baja' ,  1:'Baja', 2:'Baja', 3:'Media',3.5: 'Media', 4:'Media',5:'Media',6:'Media', 7:'Alta', 8.:'Alta',9:'Alta',10:'Alta'}

# %%
df1['depresion_map']= df1['Depression'].map(mapa1)

# %%
df1.head(2)
# Out:
#                      Age Primary streaming service  Hours per day  \
# Timestamp
# 8/27/2022 19:29:02  18.0                   Spotify            3.0
# 8/27/2022 19:57:31  63.0                   Pandora            1.5
#
#                    While working Instrumentalist Composer Fav genre  \
# Timestamp
# 8/27/2022 19:29:02           Yes             Yes      Yes     Latin
# 8/27/2022 19:57:31           Yes              No       No      Rock
#
#                    Exploratory Foreign languages    BPM  ... Frequency [Rock]  \
# Timestamp                                                ...
# 8/27/2022 19:29:02         Yes               Yes  156.0  ...            Never
# 8/27/2022 19:57:31         Yes                No  119.0  ...  Very frequently
#
#                    Frequency [Video game music] Anxiety Depression Insomnia  \
# Timestamp
# 8/27/2022 19:29:02                    Sometimes     3.0        0.0      1.0
# ...

# %%
df1.depresion_map.isnull().sum()
# Out:
# 0

# %% [markdown]
# ---

# %%
df1.Insomnia.unique()
# Out:
# array([ 1. ,  2. , 10. ,  3. ,  5. ,  7. ,  6. ,  0. ,  4. ,  8. ,  9. ,
#         3.5])

# %%
mapa2 = { 0:'Baja' ,  1:'Baja', 2:'Baja', 3:'Media',3.5: 'Media', 4:'Media',5:'Media',6:'Media', 7:'Alta', 8.:'Alta',9:'Alta',10:'Alta'}

# %%
df1['insomnio_map']= df1['Insomnia'].map(mapa2)

# %%
df1.head(2)
# Out:
#                      Age Primary streaming service  Hours per day  \
# Timestamp
# 8/27/2022 19:29:02  18.0                   Spotify            3.0
# 8/27/2022 19:57:31  63.0                   Pandora            1.5
#
#                    While working Instrumentalist Composer Fav genre  \
# Timestamp
# 8/27/2022 19:29:02           Yes             Yes      Yes     Latin
# 8/27/2022 19:57:31           Yes              No       No      Rock
#
#                    Exploratory Foreign languages    BPM  ...  \
# Timestamp                                                ...
# 8/27/2022 19:29:02         Yes               Yes  156.0  ...
# 8/27/2022 19:57:31         Yes                No  119.0  ...
#
#                    Frequency [Video game music] Anxiety Depression Insomnia  \
# Timestamp
# 8/27/2022 19:29:02                    Sometimes     3.0        0.0      1.0
# 8/27/2022 19:57:31                       Rarely     7.0        2.0      2.0
#
# ...

# %%
df1.insomnio_map.isnull().sum()
# Out:
# 0

# %% [markdown]
# ---

# %%
df1.OCD.unique()
# Out:
# array([ 0. ,  1. ,  2. ,  3. ,  9. ,  7. ,  4. ,  6. , 10. ,  5. ,  8. ,
#         8.5,  5.5])

# %%
mapa3 = { 0:'Baja' ,  1:'Baja', 2:'Baja', 3:'Media', 4:'Media',5:'Media',5.5: 'Media',6:'Media', 7:'Alta', 8.:'Alta',8.5: 'Alta',9:'Alta',10:'Alta'}

# %%
df1['toc_map']= df1['OCD'].map(mapa3)

# %%
df1.head(2)
# Out:
#                      Age Primary streaming service  Hours per day  \
# Timestamp
# 8/27/2022 19:29:02  18.0                   Spotify            3.0
# 8/27/2022 19:57:31  63.0                   Pandora            1.5
#
#                    While working Instrumentalist Composer Fav genre  \
# Timestamp
# 8/27/2022 19:29:02           Yes             Yes      Yes     Latin
# 8/27/2022 19:57:31           Yes              No       No      Rock
#
#                    Exploratory Foreign languages    BPM  ... Anxiety  \
# Timestamp                                                ...
# 8/27/2022 19:29:02         Yes               Yes  156.0  ...     3.0
# 8/27/2022 19:57:31         Yes                No  119.0  ...     7.0
#
#                    Depression Insomnia  OCD Music effects    Permissions  \
# Timestamp
# 8/27/2022 19:29:02        0.0      1.0  0.0           NaN  I understand.
# 8/27/2022 19:57:31        2.0      2.0  1.0           NaN  I understand.
#
# ...

# %%
df1.toc_map.isnull().sum()
# Out:
# 0

# %% [markdown]
# ---

# %%
df1.describe().T
# Out:
#                count          mean           std   min    25%    50%    75%  \
# Age            735.0  2.520680e+01  1.205497e+01  10.0   18.0   21.0   28.0
# Hours per day  736.0  3.572758e+00  3.028199e+00   0.0    2.0    3.0    5.0
# BPM            629.0  1.589948e+06  3.987261e+07   0.0  100.0  120.0  144.0
# Anxiety        736.0  5.837636e+00  2.793054e+00   0.0    4.0    6.0    8.0
# Depression     736.0  4.796196e+00  3.028870e+00   0.0    2.0    5.0    7.0
# Insomnia       736.0  3.738451e+00  3.088689e+00   0.0    1.0    3.0    6.0
# OCD            736.0  2.637228e+00  2.842017e+00   0.0    0.0    2.0    5.0
#
#                        max
# Age                   89.0
# Hours per day         24.0
# BPM            999999999.0
# Anxiety               10.0
# Depression            10.0
# Insomnia              10.0
# OCD                   10.0

# %%
df1['Age'].fillna(df1['Age'].mode ,inplace = True)

# %% [markdown]
# ---

# %%
df1['BPM'].fillna(df1['BPM'].median ,inplace = True)

# %% [markdown]
# ---

# %%
print(f'Los nulos de este df son:')
df1.stb.missing()
# Out:
# Los nulos de este df son:
#                               missing  total   percent
# Music effects                       8    736  1.086957
# Instrumentalist                     4    736  0.543478
# Foreign languages                   4    736  0.543478
# While working                       3    736  0.407609
# Primary streaming service           1    736  0.135870
# Composer                            1    736  0.135870
# Insomnia                            0    736  0.000000
# Frequency [Rap]                     0    736  0.000000
# Frequency [Rock]                    0    736  0.000000
# Frequency [Video game music]        0    736  0.000000
# Anxiety                             0    736  0.000000
# Depression                          0    736  0.000000
# Age                                 0    736  0.000000
# OCD                                 0    736  0.000000
# Frequency [Pop]                     0    736  0.000000
# Permissions                         0    736  0.000000
# ...

# %%
df1.dropna(subset= ["Music effects"], how = "any", inplace = True)

# %%
df1.dropna(subset= ["Instrumentalist"], how = "any", inplace = True)

# %%
df1.dropna(subset= ["Foreign languages"], how = "any", inplace = True)

# %%
df1.columns
# Out:
# Index(['Age', 'Primary streaming service', 'Hours per day', 'While working',
#        'Instrumentalist', 'Composer', 'Fav genre', 'Exploratory',
#        'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions', 'anxiety_map', 'depresion_map', 'insomnio_map',
#        'toc_map'],
#       dtype='object')

# %%
df1.dropna(subset= ['While working'], how = "any", inplace = True)

# %%
df1.dropna(subset= ['Primary streaming service'], how = "any", inplace = True)
df1.reset_index(inplace = True)

# %%
print(f'Los nulos de este df son:')
df1.stb.missing()
# Out:
# Los nulos de este df son:
#                               missing  total  percent
# Timestamp                           0    719      0.0
# Frequency [Latin]                   0    719      0.0
# Frequency [Metal]                   0    719      0.0
# Frequency [Pop]                     0    719      0.0
# Frequency [R&B]                     0    719      0.0
# Frequency [Rap]                     0    719      0.0
# Frequency [Rock]                    0    719      0.0
# Frequency [Video game music]        0    719      0.0
# Anxiety                             0    719      0.0
# Depression                          0    719      0.0
# Insomnia                            0    719      0.0
# OCD                                 0    719      0.0
# Music effects                       0    719      0.0
# Permissions                         0    719      0.0
# anxiety_map                         0    719      0.0
# depresion_map                       0    719      0.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719 entries, 0 to 718
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     719 non-null    object
#  1   Age                           719 non-null    object
#  2   Primary streaming service     719 non-null    object
#  3   Hours per day                 719 non-null    float64
#  4   While working                 719 non-null    object
#  5   Instrumentalist               719 non-null    object
#  6   Composer                      719 non-null    object
#  7   Fav genre                     719 non-null    object
#  8   Exploratory                   719 non-null    object
#  9   Foreign languages             719 non-null    object
#  10  BPM                           719 non-null    object
#  11  Frequency [Classical]         719 non-null    object
# ...

# %%
df1.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions', 'anxiety_map', 'depresion_map', 'insomnio_map',
#        'toc_map'],
#       dtype='object')

# %%
df1['Hours per day'].unique()
# Out:
# array([ 4.  ,  2.5 ,  5.  ,  3.  ,  1.  ,  6.  ,  8.  ,  2.  , 12.  ,
#        24.  ,  0.5 ,  0.25,  7.  , 10.  ,  1.5 ,  9.  ,  0.7 ,  4.5 ,
#        20.  , 16.  , 15.  ,  0.  , 14.  ,  0.1 , 11.  , 18.  ])

# %%
df1.Age.unique()
# Out:
# array([18.0, 61.0, 21.0, 19.0, <bound method Series.mode of Timestamp
#                                8/27/2022 19:29:02     18.0
#                                8/27/2022 19:57:31     63.0
#                                8/27/2022 21:28:18     18.0
#                                8/27/2022 21:40:40     61.0
#                                8/27/2022 21:54:47     18.0
#                                                       ...
#                                10/30/2022 14:37:28    17.0
#                                11/1/2022 22:26:42     18.0
#                                11/3/2022 23:24:38     19.0
#                                11/4/2022 17:31:47     19.0
#                                11/9/2022 1:55:20      29.0
#                                Name: Age, Length: 736, dtype: object>,
#        17.0, 16.0, 15.0, 14.0, 20.0, 26.0, 23.0, 37.0, 36.0, 24.0, 22.0,
#        25.0, 32.0, 29.0, 41.0, 31.0, 33.0, 30.0, 43.0, 28.0, 34.0, 13.0,
# ...

# %%
df1.to_csv('data/01-efectos_musica_encuesta.csv')

# %%
df1['Anxiety'].unique()
# Out:
# array([ 7. ,  9. ,  8. ,  4. ,  5. ,  2. ,  1. ,  6. , 10. ,  3. ,  0. ,
#         7.5])

# %% [markdown]
# ---

# %%
df1.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions', 'anxiety_map', 'depresion_map', 'insomnio_map',
#        'toc_map'],
#       dtype='object')

# %% [markdown]
# # TOC

# %%
mapa6 = { 0:'No', 1:'No', 2:'Si', 3:'Si', 4:'Si',5:'Si',5.5: 'Si',6:'Si', 7:'Si', 8.:'Si',8.5: 'Si',9:'Si',10:'Si'}

# %%
df1['toc_ppio']= df1['OCD'].map(mapa6)

# %%
mapa7 = { 0:'TOC', 1:'TOC', 2:'TOC', 3:'TOC', 4:'TOC',5:'TOC',5.5: 'TOC',6:'TOC', 7:'TOC', 8.:'TOC',8.5: 'TOC',9:'TOC',10:'TOC'}

# %%
df1['TOC_TOC']= df1['OCD'].map(mapa7)

# %% [markdown]
# ---

# %%
# Ansiedad
mapa8 = { 0:'No' ,  1:'No', 2:'Si', 3:'Si',4:'Si',5:'Si',6:'Si', 7:'Si', 7.5:'Si', 8.:'Si',9:'Si',10:'Si'}

# %%
df1['ansiedad_ppio']= df1['Anxiety'].map(mapa8)

# %%
mapa9 = { 0:'Ansiedad' ,  1:'Ansiedad', 2:'Ansiedad', 3:'Ansiedad',4:'Ansiedad',5:'Ansiedad',6:'Ansiedad', 7:'Ansiedad', 7.5:'Ansiedad', 8.:'Ansiedad',9:'Ansiedad',10:'Ansiedad'}

# %%
df1['ansiedad_ansiedad']= df1['Anxiety'].map(mapa9)

# %% [markdown]
# ---

# %%
# Insomnio
mapa10 = { 0:'No' ,  1:'No', 2:'Si', 3:'Si',3.5: 'Si', 4:'Si',5:'Si',6:'Si', 7:'Si', 8.:'Si',9:'Si',10:'Si'}

# %%
df1['insomnio_ppio']= df1['Anxiety'].map(mapa10)

# %%
mapa11 = { 0:'Insomnio' ,  1:'Insomnio', 2:'Insomnio', 3:'Insomnio',3.5: 'Insomnio', 4:'Insomnio',5:'Insomnio',6:'Insomnio', 7:'Insomnio', 8.:'Insomnio',9:'Insomnio',10:'Insomnio'}

# %%
df1['insomnio_insomnio']= df1['Insomnia'].map(mapa11)

# %% [markdown]
# ---

# %%
# Depresion
mapa12 = { 0:'No' ,  1:'No', 2:'Si', 3:'Si',3.5: 'Si', 4:'Si',5:'Si',6:'Si', 7:'Si', 8.:'Si',9:'Si',10:'Si'}

# %%
df1['depresion_ppio']= df1['Depression'].map(mapa12)

# %%
mapa13 = { 0:'Depresión' , 
            1:'Depresión',
            2:'Depresión', 
            3:'Depresión',
            3.5:'Depresión',
            4:'Depresión',
            5:'Depresión',
            6:'Depresión', 
            7:'Depresión', 
            8.:'Depresión',
            9:'Depresión',
            10:'Depresión'}

# %%
df1['depresion_depresion']= df1['Depression'].map(mapa13)

# %%
df1.to_csv('data/02-efectos_musica_encuesta.csv')

# %%
df1.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 1  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 2  8/27/2022 21:54:47  18.0                   Spotify            4.0
# 3  8/27/2022 21:56:50  18.0                   Spotify            5.0
# 4  8/27/2022 22:00:29  18.0             YouTube Music            3.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0            No              No       No  Video game music          No
# 1           Yes              No      Yes              Jazz         Yes
# 2           Yes              No       No               R&B         Yes
# 3           Yes             Yes      Yes              Jazz         Yes
# 4           Yes             Yes       No  Video game music         Yes
#
#   Foreign languages  ... insomnio_map toc_map toc_ppio TOC_TOC ansiedad_ppio  \
# ...
